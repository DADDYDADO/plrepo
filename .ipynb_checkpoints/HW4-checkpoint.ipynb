# %%
import pandas as pd
data = pd.read_csv("weightlifting_721_workouts.csv")

# %%
# the last five data of the list
data.tail()
# Out:
#                      Date        Workout Name               Exercise Name  \
# 9927  2018-09-29 14:35:32  Push - Incline #40  Low Incline Dumbbell Bench
# 9928  2018-09-29 14:35:32  Push - Incline #40  Low Incline Dumbbell Bench
# 9929  2018-09-29 14:35:32  Push - Incline #40   Lateral Raise (Dumbbells)
# 9930  2018-09-29 14:35:32  Push - Incline #40   Lateral Raise (Dumbbells)
# 9931  2018-09-29 14:35:32  Push - Incline #40   Lateral Raise (Dumbbells)
#
#       Set Order  Weight  Reps  Distance  Seconds Notes Workout Notes
# 9927          2   170.0    12       0.0        0   NaN           NaN
# 9928          3   170.0    15       0.0        0   NaN           NaN
# 9929          1    50.0    15       0.0        0   NaN           NaN
# 9930          2    50.0    15       0.0        0   NaN           NaN
# 9931          3    50.0    15       0.0        0   NaN           NaN

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
exercise_name = data["Exercise Name"]
times = data["Reps"]

# %%
data_top_20 = data[:20]
data_top_20
# Out:
#                    Date Workout Name                  Exercise Name  \
# 0   2015-10-23 17:06:37        Chest  Incline Bench Press (Barbell)
# 1   2015-10-23 17:06:37        Chest  Incline Bench Press (Barbell)
# 2   2015-10-23 17:06:37        Chest  Incline Bench Press (Barbell)
# 3   2015-10-23 17:06:37        Chest  Incline Bench Press (Barbell)
# 4   2015-10-23 17:06:37        Chest  Incline Bench Press (Barbell)
# 5   2015-10-23 17:06:37        Chest  Incline Bench Press (Barbell)
# 6   2015-10-23 17:06:37        Chest  Incline Bench Press (Barbell)
# 7   2015-10-23 17:06:37        Chest                  Weighted dips
# 8   2015-10-23 17:06:37        Chest                  Weighted dips
# 9   2015-10-23 17:06:37        Chest                  Weighted dips
# 10  2015-10-23 17:06:37        Chest                  Weighted dips
# 11  2015-10-23 17:06:37        Chest            Incline Bench Press
# 12  2015-10-23 17:06:37        Chest            Incline Bench Press
# ...

# %%
data_top_20 = data[['Exercise Name', 'Reps']].groupby(['Exercise Name']).sum().sort_values('Reps', ascending=False).head(20)

# 繪製圖表
plt.bar(data_top_20.index, data_top_20['Reps'])
plt.xticks(rotation=90)
plt.xlabel('Exercise Name')
plt.ylabel('Total Reps')
plt.title('Top 20 Exercises by Total Reps')
plt.show()

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# ...
#      -------------------------------------- 152.1/152.1 kB 1.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from os import path
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# %%
# 獲取當前文件路徑
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
# 獲取文本text
text = open(path.join(d,'weightlifting_721_workout.txt')).read()
# 生成詞雲
wc = WordCloud(scale=2,max_font_size = 100)
wc.generate_from_text(text)
# 顯示圖像
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.tight_layout()
#存儲圖像
wc.to_file('1900_basic.png')
plt.show()
