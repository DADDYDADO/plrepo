# %%
import pandas as pd
data = pd.read_csv("Seasons_Stats.csv")

# %%
# the last five data of the list
data.tail()
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 24686       24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0
#
#            MP   PER  ...    FT%    ORB    DRB    TRB   AST   STL   BLK   TOV  \
# 24686  1725.0  16.7  ...  0.679  135.0  270.0  405.0  99.0  62.0  58.0  65.0
# 24687   525.0  13.0  ...  0.564   43.0   81.0  124.0  42.0   7.0  21.0  20.0
# 24688   108.0   7.3  ...  0.600   11.0   24.0   35.0   4.0   2.0   5.0   3.0
# 24689   843.0   6.9  ...  0.775   15.0  110.0  125.0  36.0  15.0  16.0  40.0
# 24690   609.0  17.0  ...  0.653   41.0  118.0  159.0  30.0  14.0  33.0  30.0
#
#           PF    PTS
# 24686  189.0  639.0
# 24687   61.0  178.0
# 24688   17.0   23.0
# 24689   78.0  240.0
# 24690   66.0  284.0
#
# [5 rows x 53 columns]

# %%
from tabulate import tabulate

# 筛选出"Year"列为2017的数据
filtered_data = data[data["Year"] == 2017]

# 根据"PTS"列对数据进行降序排序
sorted_data = filtered_data.sort_values(by="PTS", ascending=False)

# 获取前二十位得分最高的球员
top_20_players = sorted_data.head(20)[["Player","PTS"]]

# 打印结果
print(tabulate(top_20_players, headers='keys', tablefmt='psql'))
# Out:
# +-------+-----------------------+-------+
# |       | Player                |   PTS |
# |-------+-----------------------+-------|
# | 24654 | Russell Westbrook     |  2558 |
# | 24306 | James Harden          |  2356 |
# | 24612 | Isaiah Thomas         |  2199 |
# | 24218 | Anthony Davis         |  2099 |
# | 24625 | Karl-Anthony Towns    |  2061 |
# | 24421 | Damian Lillard        |  2024 |
# | 24226 | DeMar DeRozan         |  2020 |
# | 24216 | Stephen Curry         |  1999 |
# | 24365 | LeBron James          |  1954 |
# | 24206 | DeMarcus Cousins      |  1942 |
# | 24658 | Andrew Wiggins        |  1933 |
# | 24414 | Kawhi Leonard         |  1888 |
# | 24443 | C.J. McCollum         |  1837 |
# | 24115 | Giannis Antetokounmpo |  1832 |
# | 24645 | Kemba Walker          |  1830 |
# | 24360 | Kyrie Irving          |  1816 |
# | 24175 | Jimmy Butler          |  1816 |
# | 24646 | John Wall             |  1805 |
# | 24137 | Bradley Beal          |  1779 |
# | 24278 | Paul George           |  1775 |
# +-------+-----------------------+-------+

# %%
import matplotlib.pyplot as plt

# 假设你已经将数据存储在名为df的Pandas数据帧中

# 筛选出"Year"列为2017的数据
filtered_data = data[data["Year"] == 2017]

# 根据"PTS"列对筛选后的数据进行降序排序
sorted_data = filtered_data.sort_values(by="PTS", ascending=False)

# 获取前二十位得分最高的球员的"Player"和"PTS"值
top_20_players = sorted_data.head(20)

# 提取球员名称和得分数据
players = top_20_players["Player"]
pts = top_20_players["PTS"]

# 设置图形大小
plt.figure(figsize=(8, 8))

# 绘制饼图
plt.pie(pts, labels=players, autopct='%1.1f%%')
plt.axis('equal')  # 使饼图为正圆形
plt.title("Top 20 Players' PTS in 2017")  # 添加标题
plt.show()
